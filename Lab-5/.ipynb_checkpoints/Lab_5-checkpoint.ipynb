# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Обрати реальні дані з kaggle або сгенерувати випадкові дані, що містять розподіл деякої ознаки в двох групах.

# %%
database = pd.read_csv("blkjckhands.csv", encoding = 'utf-8')
database
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data = pd.DataFrame({
    'AveragePrice':database['AveragePrice'],      
    'type':database['type']
})

data
# Out:
#        AvgPrs          Type
# 0        1.33  conventional
# 1        1.35  conventional
# 2        0.93  conventional
# 3        1.08  conventional
# 4        1.28  conventional
# ...       ...           ...
# 18244    1.63       organic
# 18245    1.71       organic
# 18246    1.87       organic
# 18247    1.93       organic
# 18248    1.62       organic
#
# [18249 rows x 2 columns]

# %%
g = sns.FacetGrid(database, col="AveragePrice", height= 8)
g = g.map(plt.hist, "type");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f0010354d9b3> in <module>
# ----> 1 g = sns.FacetGrid(database, col="AveragePrice", height= 8)
#       2 g = g.map(plt.hist, "type");
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     373
#     374         # Make the axes look good
# --> 375         fig.tight_layout()
#     376         if despine:
#     377             self.despine()
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2470
#    2471         if renderer is None:
# -> 2472             renderer = get_renderer(self)
#    2473
# ...
